# %% [markdown]
# # Smooth capacitor library

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_to_cmatrix = 'smooth_capacitor/smooth_capacitor_capacitance_library_sim_output_results.csv'
cmatrix = pd.read_csv(path_to_cmatrix)

# %%
C12 = cmatrix["C12"].values
finger_control = cmatrix["finger_control"].values

# %%
plt.plot(finger_control, C12)
